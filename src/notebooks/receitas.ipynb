# %% [markdown]
# # Receitas de candidatos

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import seaborn as sn

# %%
df_2018 = pd.read_csv('../datasets/receitas_candidatos_2018.csv', encoding='ISO-8859-1', sep=';')
df_2022 = pd.read_csv('../datasets/receitas_candidatos_2022.csv', encoding='ISO-8859-1', sep=';')

# %%
df_2018.head()
# Out:
#    Ano de eleição        Cargo Espécie receita Fonte de receita Município  \
# 0            2018  1º Suplente        Estimado  OUTROS RECURSOS         -
# 1            2018  1º Suplente        Estimado  OUTROS RECURSOS         -
# 2            2018  1º Suplente        Estimado  OUTROS RECURSOS         -
# 3            2018  1º Suplente        Estimado  OUTROS RECURSOS         -
# 4            2018  1º Suplente        Estimado  OUTROS RECURSOS         -
#
#                       Nome candidato                       Nome doador  \
# 0  CARLOS ALBERTO DA SILVA ALCANTARA          DANIELY MOREIRA PIMENTEL
# 1  CARLOS ALBERTO DA SILVA ALCANTARA  RAIMUNDA MARIA FARIAS DE ALMEIDA
# 2     LUIZ AUGUSTO OLIVEIRA DA SILVA          MARCELO MARTINS PINHEIRO
# 3     LUIZ AUGUSTO OLIVEIRA DA SILVA        MARCOS QUEIROZ DE OLIVEIRA
# 4     LUIZ AUGUSTO OLIVEIRA DA SILVA          MARLENE DE SOUZA MARTINS
#
#              Origem da receita Partido Quilombola Região  \
# ...

# %%
df_2022.head()
# Out:
#    Ano de eleição               Cargo Espécie receita Fonte de receita  \
# 0            2022  Deputado Distrital              --   FUNDO ESPECIAL
# 1            2022  Deputado Distrital              --   FUNDO ESPECIAL
# 2            2022  Deputado Distrital              --   FUNDO ESPECIAL
# 3            2022  Deputado Distrital              --   FUNDO ESPECIAL
# 4            2022  Deputado Distrital              --   FUNDO ESPECIAL
#
#   Município                         Nome candidato Nome doador  \
# 0         -     CLÁUDIA VIRGÍNIA RODRIGUES PEREIRA       #NULO
# 1         -           CRISTIANE PEREIRA DOS SANTOS       #NULO
# 2         -          FRANCISCO DOMINGOS DOS SANTOS       #NULO
# 3         -  GISELE CRISTINE DE ALMEIDA MONTENEGRO       #NULO
# 4         -                    JOSÉ CLÁUDIO BONINA       #NULO
#
#                        Origem da receita Partido  Quilombola        Região  \
# 0  Rendimentos de aplicações financeiras    PODE         NaN  CENTRO-OESTE
# ...

# %%
print("Cargos disponíveis:", df_2018['Cargo'].unique())
# Out:
# Cargos disponíveis: ['1º Suplente' '2º Suplente' 'Deputado Distrital' 'Deputado Estadual'
#  'Deputado Federal' 'Governador' 'Não se aplica' 'Presidente' 'Senador'
#  'Vice-governador']

# %%
print("Cargos disponíveis:", df_2022['Cargo'].unique())
# Out:
# Cargos disponíveis: ['Deputado Distrital' 'Deputado Estadual' 'Deputado Federal' 'Governador'
#  'Não se aplica' 'Presidente' 'Senador']

# %%
df_presidente_2018 = df_2018[df_2018['Cargo'] == 'Presidente']
df_presidente_2018.head()
# Out:
#         Ano de eleição       Cargo Espécie receita Fonte de receita Município  \
# 224531            2018  Presidente              --   FUNDO ESPECIAL         -
# 224532            2018  Presidente              --   FUNDO ESPECIAL         -
# 224533            2018  Presidente              --   FUNDO ESPECIAL         -
# 224534            2018  Presidente              --   FUNDO ESPECIAL         -
# 224535            2018  Presidente              --   FUNDO ESPECIAL         -
#
#                                     Nome candidato Nome doador  \
# 224531                         CIRO FERREIRA GOMES       #NULO
# 224532                             FERNANDO HADDAD       #NULO
# 224533        GERALDO JOSÉ RODRIGUES ALCKMIN FILHO       #NULO
# 224534               JOÃO VICENTE FONTELLA GOULART       #NULO
# 224535  MARIA OSMARINA MARINA DA SILVA VAZ DE LIMA       #NULO
#
#                             Origem da receita Partido Quilombola Região  \
# ...

# %%
df_presidente_2022 = df_2022[df_2022['Cargo'] == 'Presidente']
df_presidente_2022.head()
# Out:
#         Ano de eleição       Cargo Espécie receita  Fonte de receita  \
# 182484            2022  Presidente              --    FUNDO ESPECIAL
# 182485            2022  Presidente              --  FUNDO PARTIDARIO
# 182486            2022  Presidente              --   OUTROS RECURSOS
# 182487            2022  Presidente          Cheque    FUNDO ESPECIAL
# 182488            2022  Presidente          Cheque   OUTROS RECURSOS
#
#        Município                  Nome candidato            Nome doador  \
# 182484         -       LUIZ INÁCIO LULA DA SILVA                  #NULO
# 182485         -          JAIR MESSIAS BOLSONARO                  #NULO
# 182486         -          JAIR MESSIAS BOLSONARO                  #NULO
# 182487         -  LEONARDO PÉRICLES VIEIRA ROQUE        UNIDADE POPULAR
# 182488         -          JAIR MESSIAS BOLSONARO  ADAIR ANTONIO BOLDRIN
#
#                             Origem da receita Partido  Quilombola Região  \
# ...

# %%
df_presidente_2018.shape
# Out:
# (346, 19)

# %%
df_presidente_2022.shape
# Out:
# (361195, 19)

# %%
df_presidente_2018
# Out:
#         Ano de eleição       Cargo           Espécie receita Fonte de receita  \
# 224531            2018  Presidente                        --   FUNDO ESPECIAL
# 224532            2018  Presidente                        --   FUNDO ESPECIAL
# 224533            2018  Presidente                        --   FUNDO ESPECIAL
# 224534            2018  Presidente                        --   FUNDO ESPECIAL
# 224535            2018  Presidente                        --   FUNDO ESPECIAL
# ...                ...         ...                       ...              ...
# 224872            2018  Presidente  Transferência eletrônica  OUTROS RECURSOS
# 224873            2018  Presidente  Transferência eletrônica  OUTROS RECURSOS
# 224874            2018  Presidente  Transferência eletrônica  OUTROS RECURSOS
# 224875            2018  Presidente  Transferência eletrônica  OUTROS RECURSOS
# 224876            2018  Presidente  Transferência eletrônica  OUTROS RECURSOS
#
# ...

# %%
df_presidente_2018['Origem da receita'].unique()
# Out:
# array(['Rendimentos de aplicações financeiras',
#        'Recursos de pessoas físicas', 'Recursos de partido político',
#        'Recursos de outros candidatos',
#        'Recursos de origens não identificadas',
#        'Recursos de Financiamento Coletivo', 'Doações pela Internet',
#        'Recursos próprios'], dtype=object)

# %%
df_presidente_2022
# Out:
#         Ano de eleição       Cargo           Espécie receita  \
# 182484            2022  Presidente                        --
# 182485            2022  Presidente                        --
# 182486            2022  Presidente                        --
# 182487            2022  Presidente                    Cheque
# 182488            2022  Presidente                    Cheque
# ...                ...         ...                       ...
# 543674            2022  Presidente  Transferência eletrônica
# 543675            2022  Presidente  Transferência eletrônica
# 543676            2022  Presidente  Transferência eletrônica
# 543677            2022  Presidente  Transferência eletrônica
# 543678            2022  Presidente  Transferência eletrônica
#
#         Fonte de receita Município                       Nome candidato  \
# 182484    FUNDO ESPECIAL         -            LUIZ INÁCIO LULA DA SILVA
# 182485  FUNDO PARTIDARIO         -               JAIR MESSIAS BOLSONARO
# ...

# %%
df_presidente_2022['Origem da receita'].unique()
# Out:
# array(['Rendimentos de aplicações financeiras',
#        'Recursos de partido político', 'Recursos de pessoas físicas',
#        'Recursos de outros candidatos', 'Recursos próprios',
#        'Recursos de Financiamento Coletivo'], dtype=object)
